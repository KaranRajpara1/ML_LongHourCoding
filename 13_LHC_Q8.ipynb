# %% [markdown]
# Question 8:
# Distribution of the reputation of users whose questions are closed as
# duplicates

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
from matplotlib.ticker import PercentFormatter

# %%
from google.colab import drive

# %%
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
cd "/content/drive/MyDrive/MachineLearning_LHC/Arjun_Assignment_data/dataset"
# Out:
# /content/drive/MyDrive/MachineLearning_LHC/Arjun_Assignment_data/dataset

# %%
ls
# Out:
# post_history.csv  postLinks.json  posts_long.json  users.csv
# postLinks.csv     posts_long.csv  posts_short.csv

# %%
dataset5 = pd.read_csv('posts_short.csv')
print(dataset5)
# Out:
#         Unnamed: 0        id  post_type_id  accepted_answer_id  parent_id  \
# 0                0         4             1                   7       -999
# 1                1         6             1                  31       -999
# 2                2         9             1                1404       -999
# 3                3        11             1                1248       -999
# 4                4        13             1                -999       -999
# ...            ...       ...           ...                 ...        ...
# 676199      676199  52133457             1                -999       -999
# 676200      676200  52133674             1                -999       -999
# 676201      676201  52133700             1                -999       -999
# 676202      676202  52133880             1                -999       -999
# 676203      676203  52134121             1                -999       -999
#
#                   creation_date  score  view_count  owner_user_id  \
# ...

# %%
dataset5.describe()
# Out:
#           Unnamed: 0            id  post_type_id  accepted_answer_id  \
# count  676204.000000  6.762040e+05      676204.0        6.762040e+05
# mean   338101.500000  2.584291e+07           1.0        1.166794e+07
# std    195203.425051  1.586292e+07           0.0        1.531875e+07
# min         0.000000  4.000000e+00           1.0       -9.990000e+02
# 25%    169050.750000  1.170959e+07           1.0       -9.990000e+02
# 50%    338101.500000  2.566376e+07           1.0        2.574750e+06
# 75%    507152.250000  3.999613e+07           1.0        2.095320e+07
# max    676203.000000  5.213412e+07           1.0        5.213268e+07
#
#        parent_id          score    view_count  owner_user_id   answer_count  \
# count   676204.0  676204.000000  6.762040e+05   6.762040e+05  676204.000000
# mean      -999.0      14.731906  1.549030e+04   2.891993e+06       2.415215
# std          0.0      97.924320  7.056748e+04   2.703980e+06       3.403235
# ...

# %%
dataset5.head(5)
# Out:
#    Unnamed: 0  id  post_type_id  accepted_answer_id  parent_id  \
# 0           0   4             1                   7       -999
# 1           1   6             1                  31       -999
# 2           2   9             1                1404       -999
# 3           3  11             1                1248       -999
# 4           4  13             1                -999       -999
#
#              creation_date  score  view_count  owner_user_id  \
# 0  2008-07-31T21:42:52.667    573       37080              8
# 1  2008-07-31T22:08:08.620    256       16306              9
# 2  2008-07-31T23:40:59.743   1743      480476              1
# 3  2008-07-31T23:55:37.967   1348      136033              1
# 4  2008-08-01T00:42:38.903    539      157009              9
#
#                                                 tags  answer_count  \
# 0  <c#><floating-point><type-conversion><double><...            13
# 1             <html><css><css3><internet-explorer-7>             5
# ...

# %%
dataset1 = pd.read_csv('post_history.csv')
dataset1.head(3)
# Out:
#    Unnamed: 0  id  ph_type_id  post_id                         revision_guid  \
# 0           0  12           1       17  0421fb42-a29a-4cb2-84ba-a828725410f8
# 1           1  13           3       17  0421fb42-a29a-4cb2-84ba-a828725410f8
# 2           2  14           2       17  0421fb42-a29a-4cb2-84ba-a828725410f8
#
#              creation_date  user_id user_display_name comment  \
# 0  2008-08-01T05:09:55.993        2               NaN     NaN
# 1  2008-08-01T05:09:55.993        2               NaN     NaN
# 2  2008-08-01T05:09:55.993        2               NaN     NaN
#
#                                    text
# 0                  Binary Data in MYSQL
# 1                     <database><mysql>
# 2  How do I store binary data in mysql?

# %%
dataset1.describe()
# Out:
#          Unnamed: 0            id    ph_type_id       post_id       user_id
# count  3.641001e+06  3.641001e+06  3.641001e+06  3.641001e+06  3.641001e+06
# mean   1.820500e+06  8.433379e+07  4.661764e+00  2.518253e+07  2.210658e+06
# std    1.051067e+06  5.612531e+07  4.878259e+00  1.598161e+07  2.546301e+06
# min    0.000000e+00  1.200000e+01  1.000000e+00  4.000000e+00 -9.990000e+02
# 25%    9.102500e+05  3.187098e+07  2.000000e+00  1.086864e+07  1.714560e+05
# 50%    1.820500e+06  8.160875e+07  3.000000e+00  2.455296e+07  1.171391e+06
# 75%    2.730750e+06  1.353667e+08  5.000000e+00  3.948462e+07  3.544995e+06
# max    3.641000e+06  1.809541e+08  5.000000e+01  5.213456e+07  1.030568e+07

# %%
dataset2 = pd.read_csv('users.csv')
dataset2.head(3)
# Out:
#    Unnamed: 0  id  reputation            creation_date  display_name   views  \
# 0           0  -1           1  2008-07-31T00:00:00.000     Community     649
# 1           1   1       44300  2008-07-31T14:22:31.287   Jeff Atwood  408587
# 2           2   2        3491  2008-07-31T14:22:31.287  Geoff Dalgas   23966
#
#    upvotes  downvotes  account_id
# 0   274835     980920          -1
# 1     3367       1309           1
# 2      650         88           2

# %%
dataset2.describe()
# Out:
#          Unnamed: 0            id    reputation         views       upvotes  \
# count  9.321924e+06  9.321924e+06  9.321924e+06  9.321924e+06  9.321924e+06
# mean   4.660962e+06  5.436383e+06  1.100237e+02  1.475809e+01  1.186146e+01
# std    2.691008e+06  2.860518e+06  2.271570e+03  6.928529e+02  1.693500e+02
# min    0.000000e+00 -1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.330481e+06  3.007626e+06  1.000000e+00  0.000000e+00  0.000000e+00
# 50%    4.660962e+06  5.483160e+06  1.000000e+00  0.000000e+00  0.000000e+00
# 75%    6.991442e+06  7.907841e+06  8.000000e+00  3.000000e+00  0.000000e+00
# max    9.321923e+06  1.030561e+07  1.047863e+06  1.684703e+06  2.748350e+05
#
#           downvotes    account_id
# count  9.321924e+06  9.321924e+06
# mean   1.547975e+00  7.042674e+06
# std    3.363773e+02  4.117172e+06
# min    0.000000e+00 -9.990000e+02
# 25%    0.000000e+00  3.455831e+06
# 50%    0.000000e+00  6.969262e+06
# 75%    0.000000e+00  1.059218e+07
# ...

# %%
new_dataset2 = dataset2.copy()
new_dataset2.rename(columns = {'id':'user_id'}, inplace = True)

# %%
dataset1_copy = dataset1.copy()

# %%
myData = pd.merge(dataset1_copy,new_dataset2,on='user_id')

# %%
myData.head(3)
# Out:
#    Unnamed: 0_x  id  ph_type_id  post_id  \
# 0             0  12           1       17
# 1             1  13           3       17
# 2             2  14           2       17
#
#                           revision_guid          creation_date_x  user_id  \
# 0  0421fb42-a29a-4cb2-84ba-a828725410f8  2008-08-01T05:09:55.993        2
# 1  0421fb42-a29a-4cb2-84ba-a828725410f8  2008-08-01T05:09:55.993        2
# 2  0421fb42-a29a-4cb2-84ba-a828725410f8  2008-08-01T05:09:55.993        2
#
#   user_display_name comment                                  text  \
# 0               NaN     NaN                  Binary Data in MYSQL
# 1               NaN     NaN                     <database><mysql>
# 2               NaN     NaN  How do I store binary data in mysql?
#
#    Unnamed: 0_y  reputation          creation_date_y  display_name  views  \
# 0             2        3491  2008-07-31T14:22:31.287  Geoff Dalgas  23966
# 1             2        3491  2008-07-31T14:22:31.287  Geoff Dalgas  23966
# ...

# %%
dataset3 = pd.read_csv('postLinks.csv')
dataset3.head(3)
# Out:
#    Unnamed: 0  id            creation_date  post_id  related_post_id  \
# 0           0  19  2010-04-26T02:59:48.130      109            32412
# 1           1  37  2010-04-26T02:59:48.600     1970           617600
# 2           2  42  2010-04-26T02:59:48.647     2154          2451138
#
#    link_type_id
# 0             1
# 1             1
# 2             1

# %%
co = 1
qqq = list()
for i in dataset3.values:
    if co == 10:
        break
    pID = i[3]
    #print(myData[myData['post_id'] == pID])
    xyz = myData[myData['post_id'] == pID]
    # if len(xyz) != 0:
    #     print(xyz['reputation'])
    #     qqq.append(xyz['reputation'])
    qqq.append(xyz['reputation'])
    co += 1

# %%
qqq
# Out:
# [Series([], Name: reputation, dtype: int64),
#  Series([], Name: reputation, dtype: int64),
#  Series([], Name: reputation, dtype: int64),
#  1896      113539
#  1897      113539
#  1898      113539
#  43521          1
#  302048         1
#  654758     28408
#  Name: reputation, dtype: int64,
#  Series([], Name: reputation, dtype: int64),
#  Series([], Name: reputation, dtype: int64),
#  Series([], Name: reputation, dtype: int64),
#  1672      8133
#  2309     41167
#  2310     41167
#  2311     41167
#  2816     17039
#  4716      7773
#  16396        1
#  Name: reputation, dtype: int64,
#  Series([], Name: reputation, dtype: int64)]
